# %% [markdown]
# <a href="https://colab.research.google.com/github/Neenz-123/Physiopro/blob/main/appointment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url='https://raw.githubusercontent.com/gradenceglobal-lgtm/physiocare-clinic-analysis-v8/refs/heads/main/data/appointments.csv?token=GHSAT0AAAAAAD2UIIBIAEKEZ6NL3RDRRQ6E2PCC24Q'

# %%
df = pd.read_csv(url)

# %%
print(df.head())
# Out:
#   appointment_id patient_id staff_id appointment_date appointment_time  \
# 0      AP0000001    PT00047    ST005       2023-09-01            12:00
# 1      AP0000002    PT00047    ST005       2023-09-04            15:45
# 2      AP0000003    PT00047    ST004       2023-09-18            09:45
# 3      AP0000004    PT00047    ST002       2023-10-09            10:30
# 4      AP0000005    PT00047    ST001       2023-10-23            11:15
#
#      appointment_type     status booking_channel booking_created_date  \
# 0  Initial Assessment  cancelled         Walk-in           2023-08-22
# 1  Initial Assessment  completed           Phone           2023-09-01
# 2           Follow-up  completed           Phone           2023-09-09
# 3           Follow-up  completed  Reception Call           2023-09-30
# 4       Rehab Session  completed  Reception Call           2023-10-20
#
#    lead_days    status_updated_at
# 0         16  2023-09-01 01:00:00
# 1          2  2023-09-06 00:00:00
# ...

# %%
df.to_csv("appointments.csv", index=False)
